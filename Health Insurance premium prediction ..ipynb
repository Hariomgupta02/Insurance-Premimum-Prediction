# %% [markdown]
# # Description
#  The obejective of the insurance  dataset is to predict charges.The datasets consists of several predictor(independent)        variables and one target varible(charges).
#  Dataset url:
# # Name of the columns with their meanings
#   1) Age: age of primary beneficiary
#   2) Sex: insurance contractor gender female,male
#   3) Bmi: Body mass index,providing an understanding of the body, weights that are relatively high or low relative to             height,objective index of the body weight(kg/ m^2)using the ratio of height to weight,idealy 18.5 to 24.9
#   4) Children: Number of children covered by health insurance / Number of dependents
#   5) Smoker: Smoking
#   6) Region: The beneficary's residential in the US, northeast,southeast,southwest,northwest.
#   7) Charges: Individual medical costs billed by health insurance
# # Step 1: Importing libraries like Numpy,Pandas,Matplotlib,Seaborn and Sciket learn(sklearn)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2:Load the Dataset

# %%
df=pd.read_csv("insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# # Step 3: Exploratory Data Analysis
# Exploratory Data Analysis(EDA), also known as Data Exploration, is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.
# In this step,we will perform the below operations:
# # 3.1) Understanding the variables
#       3.1.1) Head of the dataset
#       3.1.2) The shape of the dataset
#       3.1.3) List types of all columns
#       3.1.4) Info of the dataset
#       3.1.5) Summary of the dataset
# # 3.2) Data cleaning
#       3.2.1) Check the duplicates
#       3.2.2) Check the null values

# %% [markdown]
# # univariate data analysis

# %%
plt.hist(df['age'],bins=10)
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['age'],color='red')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
# box plot is used on numerical data
sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
# hist is used on numerical data
df.hist(bins=20,edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'children'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # bivariate data analysis

# %% [markdown]
# # 1. scatterplot(Numerical-Numerical)

# %%
crosstab=pd.crosstab(df['sex'],df['region'])
crosstab
# Out:
# region  northeast  northwest  southeast  southwest
# sex
# female        161        164        175        162
# male          163        161        189        163

# %%
total_row = crosstab.sum(axis=0)
crosstab.loc['Total']=total_row
print(crosstab)
# Out:
# region  northeast  northwest  southeast  southwest
# sex
# female        161        164        175        162
# male          163        161        189        163
# Total         324        325        364        325

# %%
sns.scatterplot(x=df['age'],y=df['charges'],hue=df['sex'],style=df['smoker'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x=df['age'],y=df['children'])
# Out:
# <Axes: xlabel='age', ylabel='children'>

# %% [markdown]
# # Bar Plot(Numerical-Categorical)

# %%
sns.barplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x=df['region'],y=df['charges'],hue=df['sex'])
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
sns.boxplot(x=df['sex'],y=df['age'],hue=df['region'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# # HeatMap (Categorical-categorical)

# %%
sns.heatmap(pd.crosstab(df['sex'],df['region']))
# Out:
# <Axes: xlabel='region', ylabel='sex'>

# %%
# Pair plot is used to plot scatter diagram b/w each numerical data
sns.pairplot(df,hue='region')

# %% [markdown]
# #   3.1.1) Head of the dataset
#       The head(n)function returns the first n rows for the object based on the position.It is useful for quickely testing        if your object has the right type of data in it.

# %%
# display first five rows of the dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#  display last five rows of the dataset
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# Display randomly any number of records of data
df.sample(4)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 291    29    male  29.640         1     no  northeast  20277.80751
# 554    25  female  41.325         0     no  northeast  17878.90068
# 1179   31    male  29.810         0    yes  southeast  19350.36890
# 453    20    male  29.735         0     no  northwest   1769.53165

# %% [markdown]
# # 3.1.2) The shape of the dataset
# This shape()function gives us the number of rows and columns of the dataset

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
#  No. of rows=1338
#
#  NO. of columns=7
# # 3.1.3) List types of all columns
# using df.dtypes, we get the list of types of all the columns in our dataset.

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# # 3.1.4) Info the dataset
#
# info() is used to check the information about the data and the datatypes  of each respective attribute.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # 3.1.5) summary of the dataset
#  The described method will help to see how data has been spread for numerical values. We can clearly see the minimum values,mean,different percentile values and maximum values

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Numerical features

# %%
[ features for features in df.dtypes[df.dtypes !='object'].index]
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
new_features=df.dtypes[df.dtypes !='object'].index

# %%
new_features
# Out:
# Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %% [markdown]
# # Distribution of categorical features

# %%
cat_features= df.dtypes[df.dtypes=='object'].index
cat_features
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
df[cat_features].describe()
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# # Check the unique lables in the categorical variables

# %%
# check the unique lable of the 'sex' variable
df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# check the no. of lables of the 'sex' variable
print(df.sex.value_counts())
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
# print the no. of lables of 'region' variable
print(df.region.value_counts())
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
# print the no. of lables of 'smoker' variable
print(df.smoker.value_counts())
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# # 3.2) Data cleaning

# %% [markdown]
# # 3.2.1) Drop the Duplicates
# check there exist any duplicates value or not, If exists then we should remove from the dataframe.

# %%
# check the shape before drop the duplicates
df.shape
# Out:
# (1338, 7)

# %%
df=df.drop_duplicates()

# %%
# check the shape after drop the dupicates
df.shape
# Out:
# (1337, 7)

# %% [markdown]
# Here before droping no. of rows =1338
#
# and after droping the duplicates,no. of rows=1337
#
# which means only one Duplicates exist now which is removed.
#
# finally, our dataset shape is=(1337,7)

# %% [markdown]
# # Check the NUll values
# Using isnull.sum()function we can see the null values present in the column in the dataset.

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# There is no Null values in the given datasets

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Converting columns from string['sex','smoker','region'] To Numerical Values

# %% [markdown]
# # One Hot Encoding

# %%
df_dummies = pd.get_dummies(df, columns=['sex','smoker','region'], drop_first=True).astype(int)

# %%
df_dummies
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes  region_northwest  \
# 0      19   27         0    16884         0           1                 0
# 1      18   33         1     1725         1           0                 0
# 2      28   33         3     4449         1           0                 0
# 3      33   22         0    21984         1           0                 1
# 4      32   28         0     3866         1           0                 1
# ...   ...  ...       ...      ...       ...         ...               ...
# 1333   50   30         3    10600         1           0                 1
# 1334   18   31         0     2205         0           0                 0
# 1335   18   36         0     1629         0           0                 0
# 1336   21   25         0     2007         0           0                 0
# 1337   61   29         0    29141         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1337 rows x 9 columns]

# %%
df_dummies.head()
# Out:
#    age  bmi  children  charges  sex_male  smoker_yes  region_northwest  \
# 0   19   27         0    16884         0           1                 0
# 1   18   33         1     1725         1           0                 0
# 2   28   33         3     4449         1           0                 0
# 3   33   22         0    21984         1           0                 1
# 4   32   28         0     3866         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df1=df_dummies

# %%
df1.shape
# Out:
# (1337, 9)

# %% [markdown]
# # 5)Split the data frame into X & Y

# %%
target_name='charges'
# Separate object for target feature
y=df1[target_name]

# Separate object for input feature
X=df1.drop(target_name, axis=1)

# %%
X.head()
# Out:
#    age  bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19   27         0         0           1                 0
# 1   18   33         1         1           0                 0
# 2   28   33         3         1           0                 0
# 3   33   22         0         1           0                 1
# 4   32   28         0         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
X.shape
# Out:
# (1337, 8)

# %%
y.shape
# Out:
# (1337,)

# %% [markdown]
# # 6) TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# ((1069, 8), (1069,))

# %%
X_test.shape,y_test.shape
# Out:
# ((268, 8), (268,))

# %% [markdown]
# # 7)Build the Regression Algorithms

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
y_train_pred=lr.predict(X_train)
y_test_pred=lr.predict(X_test)
y_test_pred.shape
# Out:
# (268,)

# %% [markdown]
# # Evaluation Matrics

# %%
# train score
train_score=lr.score(X_train,y_train)
print('Train_score:', train_score)
# Out:
# Train_score: 0.7528978941229244

# %%
# R_2 Score
from sklearn.metrics import r2_score
score=r2_score(y_test,y_test_pred)
print('r_2 score',score)
# Out:
# r_2 score 0.7405079756533047

# %%
X_test.shape[1]
# Out:
# 8

# %%
# Calculate R² score
# Number of observations and features
n = len(y_test)
k = X_test.shape[1]

# Calculate Adjusted R²
adjusted_r2 = 1 - (1 - score) * (n - 1) / (n - k - 1)
adjusted_r2
# Out:
# 0.7324927779900864

# %%
from sklearn import metrics
print("Mean Absolute Error:",metrics.mean_absolute_error(y_test,y_test_pred))
print("Mean Squared Error:",metrics.mean_squared_error(y_test,y_test_pred))
print("Root Mean Squared Error:",np.sqrt(metrics.mean_squared_error(y_test,y_test_pred)))
# Out:
# Mean Absolute Error: 4392.891886591289
# Mean Squared Error: 41917515.694839336
# Root Mean Squared Error: 6474.3737685462165

# %%
df2=pd.DataFrame({"Actual":y_test,"predicted":y_test_pred,"difference":y_test-y_test_pred})
df2
# Out:
#       Actual     predicted    difference
# 13     11090  14307.332035  -3217.332035
# 1052    9288  11186.843271  -1898.843271
# 172     1694  -1929.547052   3623.547052
# 395     7526   5654.144941   1871.855059
# 934     4673   8563.096474  -3890.096474
# ...      ...           ...           ...
# 1028    9850  11463.821329  -1613.821329
# 97     10226  13674.652046  -3448.652046
# 220     5012   7633.626400  -2621.626400
# 41      4949   8014.683367  -3065.683367
# 780    18259  28357.746259 -10098.746259
#
# [268 rows x 3 columns]

# %%
df1.head(14)
# Out:
#     age  bmi  children  charges  sex_male  smoker_yes  region_northwest  \
# 0    19   27         0    16884         0           1                 0
# 1    18   33         1     1725         1           0                 0
# 2    28   33         3     4449         1           0                 0
# 3    33   22         0    21984         1           0                 1
# 4    32   28         0     3866         1           0                 1
# 5    31   25         0     3756         0           0                 0
# 6    46   33         1     8240         0           0                 0
# 7    37   27         3     7281         0           0                 1
# 8    37   29         2     6406         1           0                 0
# 9    60   25         0    28923         0           0                 1
# 10   25   26         0     2721         1           0                 0
# 11   62   26         0    27808         0           1                 0
# 12   23   34         0     1826         1           0                 0
# 13   56   39         0    11090         0           0                 0
#
#     region_southeast  region_southwest
# 0                  0                 1
# 1                  1                 0
# 2                  1                 0
# 3                  0                 0
# 4                  0                 0
# 5                  1                 0
# 6                  1                 0
# 7                  0                 0
# 8                  0                 0
# 9                  0                 0
# 10                 0                 0
# 11                 1                 0
# 12                 0                 1
# 13                 1                 0

# %%
# predicting value of y corressponding to row 14 or index no. 13
lr.predict([[56,39,0,0,0,0,1,0]])
# Out:
# array([14307.3320354])

# %%
print("intercept",lr.intercept_)
# Out:
# intercept -11507.31646027657

# %%
print("coefficents",lr.coef_)
# Out:
# coefficents [  253.90154134   336.64500701   532.41244304   -42.13344105
#  23746.83964179  -872.13119261 -1532.99309268 -1133.4072194 ]

# %% [markdown]
# # Feature selection
# Few advantages of Feature Selection:
# 1) Faster training times
# 2) Reduce the complexity
# 3) Improved the accuracy and performance
# 4) The most important one- reduction in 'over fitting'

# %% [markdown]
# There are many different kinds of feature selection methods
# 1) Forward Selection,
# 2) Recursive feature Elimination
# 3) Backward elimination
#
# The simplest and widely used one is Backward elimination

# %% [markdown]
#  # Building optimal model using "Backward Elimination" Method

# %% [markdown]
# When we're building a machine learning model,it is very important that we select only those features or predictors  which are necessary.
# Assume we have 100 feartures or predictor in our dataset. That doesn't necessrily mean that we need to have all 100 features in our model.
#
# There are various ways in which we can find out which features have very little impact on the model and which ones we can remove from the dataset.
#
# A similar idea can be applied in Backward Elimination wheather a feature significantly impacts the output or not.
#
# A P-value helps determine weather a hypothesis must be accepted or rejected.

# %% [markdown]
# # Backward Elimination Method Procedure

# %% [markdown]
# * ## step 1
#
# The first step in backward elimination is select a significance level, or select the P-value.
#
# Usually, in most cases, a 5% significance level is selected.This means the P-value will be 0.05. You can change this value depending on the project.
#
# * ## step 2
#
# The second step is fit your machine learning model with all the features selected.
#
# So,if there are 100 features,you include all of them in your model and fit the model on your dataset.No changes here.
#
# * ## step 3
#
# In step 3,identify the feature or predictor which has the highest P- value.
#
# * ## step 4
#
# This is a significance step. Here we take decisions.In the previous step 3,we identified the feature which has the highest
# P-value. IF the P-value of this feature is greater than the significance level, we'll just jump to step 6,which means that
# we're done
#
# * ## step 5
#
# Once we find out the feature which has to removed from the dataset and we'll fit the model again with new dataset.After fitting the model for the new dataset,we'll jump back to step 3.
#
# This process continues untill we reach a point in step 4 where the highest P-value from all the remaining features in the dataset in less than the significance selected in step 1.
#
# In our example, this means we iterate from step 3 to step 5 and back till the highest P-value in the dataset is less than 0.05.
#
# Out of the 100 assumed features,we might filter out a good 10 features.
#
# * ## step 6
#  once we reach step 6, we are done with the feature selection process. We have successfully used backward elimination to filter out feature

# %%
import statsmodels.api as sm

# %%
X
# Out:
#       age  bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19   27         0         0           1                 0
# 1      18   33         1         1           0                 0
# 2      28   33         3         1           0                 0
# 3      33   22         0         1           0                 1
# 4      32   28         0         1           0                 1
# ...   ...  ...       ...       ...         ...               ...
# 1333   50   30         3         1           0                 1
# 1334   18   31         0         0           0                 0
# 1335   18   36         0         0           0                 0
# 1336   21   25         0         0           0                 0
# 1337   61   29         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1337 rows x 8 columns]

# %% [raw]
# before we begin with backward elimination, we need to append '1' at the begeining of our dataset.Now ,why is this
# important?
# The equation of our lineb(or rather,plane) is y=b+ m1.x1+ m2.x2+m3.x3+........
#
# When we make a linear model with sklearn, the bias term 'b' is calculate separately.
# However,for performing Backward elimination, we are required to use the linear model provided by statsmodel library_ which
# does not consider the bias term.
#
# Hence,by adding a dummy feature with values as '1',our equation becomes y=b.x0+m1.x1+m2.x2+m3.x3+......,where x0=1.

# %%
# add a columns of ones as integer data type 
X1=np.append(arr=np.ones((1337,1)).astype(int),values=X,axis=1)

# %%
X1.shape
# Out:
# (1337, 9)

# %%
X1[:,0]
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# choose a significance level usually 0.05, if p> 0.05
# for the highest values parameter, remove that value
X_opt=X1[:,[0,1,2,3,4,5,6,7,8]]
X_opt.shape
# Out:
# (1337, 9)

# %%
X_opt
# Out:
# array([[ 1, 19, 27, ...,  0,  0,  1],
#        [ 1, 18, 33, ...,  0,  1,  0],
#        [ 1, 28, 33, ...,  0,  1,  0],
#        ...,
#        [ 1, 18, 36, ...,  0,  1,  0],
#        [ 1, 21, 25, ...,  0,  0,  1],
#        [ 1, 61, 29, ...,  1,  0,  0]])

# %% [markdown]
# # OLS stands for "Ordinary Least Squares',which essentially trains a linear model.

# %%
ols=sm.OLS(endog=y,exog=X_opt).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     499.9
# Date:                Fri, 27 Sep 2024   Prob (F-statistic):               0.00
# Time:                        00:34:28   Log-Likelihood:                -13538.
# No. Observations:                1337   AIC:                         2.709e+04
# Df Residuals:                    1328   BIC:                         2.714e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.174e+04    975.698    -12.032      0.000   -1.37e+04   -9825.888
# x1           256.8881     11.912     21.566      0.000     233.520     280.256
# x2           338.0433     28.527     11.850      0.000     282.080     394.007
# x3           477.5731    137.903      3.463      0.001     207.042     748.104
# x4          -130.6352    333.221     -0.392      0.695    -784.332     523.061
# x5          2.386e+04    413.389     57.715      0.000     2.3e+04    2.47e+04
# x6          -342.8252    476.853     -0.719      0.472   -1278.292     592.642
# x7         -1042.6751    479.070     -2.176      0.030   -1982.492    -102.858
# x8          -969.5986    478.205     -2.028      0.043   -1907.719     -31.478
# ==============================================================================
# Omnibus:                      299.296   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              714.268
# Skew:                           1.209   Prob(JB):                    7.92e-156
# Kurtosis:                       5.641   Cond. No.                         306.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Observation
#
# From the summary, we observe that the highest P-value is for 4th feature (x4=sex) is 0.695, which is way over our significance level of 0.05. Hence, we remove 'sex' feature.

# %% [markdown]
# # Now Remove the variable x4

# %%
# Remove 2th column (x4='sex') from the X1  as its highest P- value is 0.698
# Build the ols with remaining features and check the most significance value

X_opt1=X1[:,[0,1,2,3,5,6,7,8]]
X_opt1.shape
# Out:
# (1337, 8)

# %%
ols=sm.OLS(endog=y,exog=X_opt1).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     571.7
# Date:                Fri, 27 Sep 2024   Prob (F-statistic):               0.00
# Time:                        00:34:29   Log-Likelihood:                -13538.
# No. Observations:                1337   AIC:                         2.709e+04
# Df Residuals:                    1329   BIC:                         2.713e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.179e+04    966.502    -12.200      0.000   -1.37e+04   -9895.440
# x1           256.9996     11.905     21.588      0.000     233.646     280.353
# x2           337.5187     28.487     11.848      0.000     281.634     393.403
# x3           476.6029    137.837      3.458      0.001     206.202     747.004
# x4          2.385e+04    412.075     57.869      0.000     2.3e+04    2.47e+04
# x5          -341.8514    476.695     -0.717      0.473   -1277.007     593.305
# x6         -1042.0025    478.915     -2.176      0.030   -1981.514    -102.492
# x7          -968.9077    478.050     -2.027      0.043   -1906.722     -31.093
# ==============================================================================
# Omnibus:                      299.649   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              715.831
# Skew:                           1.210   Prob(JB):                    3.62e-156
# Kurtosis:                       5.644   Cond. No.                         303.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Observation
#
# From the summary, we observe that the highest P-value for 6th feature of X1 or X5 of x_opt1(x5=northwest) is 0.473, which is way over our significance level of 0.05. Hence, we remove 'northwest' feature.

# %%
# Remove the 6th feature from X1 as it has p_value > 0.05
# Build the ols model with remaining features and check the most significane value

X_opt2=X1[:,[0,1,2,3,5,7,8]]
X_opt2.shape
# Out:
# (1337, 7)

# %%
ols=sm.OLS(endog=y,exog=X_opt2).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     667.1
# Date:                Fri, 27 Sep 2024   Prob (F-statistic):               0.00
# Time:                        00:34:29   Log-Likelihood:                -13539.
# No. Observations:                1337   AIC:                         2.709e+04
# Df Residuals:                    1330   BIC:                         2.713e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.196e+04    936.825    -12.768      0.000   -1.38e+04   -1.01e+04
# x1           257.0168     11.902     21.594      0.000     233.667     280.366
# x2           337.5287     28.482     11.851      0.000     281.655     393.403
# x3           473.5766    137.747      3.438      0.001     203.352     743.801
# x4          2.385e+04    411.878     57.914      0.000     2.3e+04    2.47e+04
# x5          -871.6733    415.791     -2.096      0.036   -1687.351     -55.995
# x6          -797.7664    414.145     -1.926      0.054   -1610.215      14.682
# ==============================================================================
# Omnibus:                      299.035   Durbin-Watson:                   2.094
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              711.948
# Skew:                           1.209   Prob(JB):                    2.53e-155
# Kurtosis:                       5.633   Cond. No.                         289.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Observation
# From the summary, we observe that the highest P-value is for 8th feature of X1 or X6 of x_opt2(x6=southwest) is 0.054, which is way over our significance level of 0.05. Hence, we remove 'southwest' feature.

# %%
# Remove the 8th(southwest) feature from X1 as it has p_value > 0.05
# Build the ols model with remaining features and check the most significane value

X_opt3=X1[:,[0,1,2,3,5,7]]
X_opt3.shape
# Out:
# (1337, 6)

# %%
ols=sm.OLS(endog=y,exog=X_opt3).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     798.2
# Date:                Fri, 27 Sep 2024   Prob (F-statistic):               0.00
# Time:                        00:34:29   Log-Likelihood:                -13540.
# No. Observations:                1337   AIC:                         2.709e+04
# Df Residuals:                    1331   BIC:                         2.712e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.207e+04    935.958    -12.900      0.000   -1.39e+04   -1.02e+04
# x1           257.1758     11.914     21.586      0.000     233.803     280.549
# x2           332.0943     28.371     11.706      0.000     276.438     387.750
# x3           470.1455    137.875      3.410      0.001     199.669     740.622
# x4          2.386e+04    412.262     57.885      0.000    2.31e+04    2.47e+04
# x5          -585.7281    388.786     -1.507      0.132   -1348.428     176.971
# ==============================================================================
# Omnibus:                      301.859   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              722.391
# Skew:                           1.218   Prob(JB):                    1.36e-157
# Kurtosis:                       5.652   Cond. No.                         289.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Observation
# From the summary, we observe that the highest P-value is for 7th feature of X1 or X5 of x_opt3 (x5=southeast) is 0.132, which is way over our significance level of 0.05. Hence, we remove 'southwest' feature..

# %%
# Remove the 7th(southwest) feature from X1 as it has p_value > 0.05
# Build the ols model with remaining features and check the most significane value
X_opt4=X1[:,[0,1,2,3,5]]
X_opt4.shape
# Out:
# (1337, 5)

# %%
ols=sm.OLS(endog=y,exog=X_opt4).fit()
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     996.2
# Date:                Fri, 27 Sep 2024   Prob (F-statistic):               0.00
# Time:                        00:34:29   Log-Likelihood:                -13542.
# No. Observations:                1337   AIC:                         2.709e+04
# Df Residuals:                    1332   BIC:                         2.712e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -1.19e+04    929.646    -12.806      0.000   -1.37e+04   -1.01e+04
# x1           257.9086     11.910     21.655      0.000     234.544     281.273
# x2           320.3455     27.291     11.738      0.000     266.808     373.883
# x3           475.6406    137.893      3.449      0.001     205.130     746.151
# x4          2.382e+04    411.456     57.893      0.000     2.3e+04    2.46e+04
# ==============================================================================
# Omnibus:                      300.493   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              717.895
# Skew:                           1.213   Prob(JB):                    1.29e-156
# Kurtosis:                       5.645   Cond. No.                         286.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# After applying feature selection we have only 5 important feature to predict charges -['constant','age','bmi',child,'smoker']
X_opt4
# Out:
# array([[ 1, 19, 27,  0,  1],
#        [ 1, 18, 33,  1,  0],
#        [ 1, 28, 33,  3,  0],
#        ...,
#        [ 1, 18, 36,  0,  0],
#        [ 1, 21, 25,  0,  0],
#        [ 1, 61, 29,  0,  1]])

# %%
X.columns
# Out:
# Index(['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northwest',
#        'region_southeast', 'region_southwest'],
#       dtype='object')

# %% [markdown]
# # TRAIN TEST SPLIT After Feature Selection

# %%
X_train,X_test,y_train,y_test=train_test_split(X_opt4,y,test_size=0.2,random_state=0)
new_model=LinearRegression()
new_model.fit(X_train,y_train)
X_train.shape,X_test.shape
# Out:
# ((1069, 5), (268, 5))

# %%
X_test
# Out:
# array([[ 1, 18, 39,  0,  0],
#        [ 1, 47, 29,  1,  0],
#        [ 1, 49, 31,  1,  0],
#        ...,
#        [ 1, 18, 26,  2,  0],
#        [ 1, 54, 25,  3,  1],
#        [ 1, 62, 30,  2,  0]])

# %%
new_train_pred=new_model.predict(X_train)
new_test_pred=new_model.predict(X_test)
new_test_pred.shape
# Out:
# (268,)

# %%
# train score after applying Backward Elimination method
train_score=new_model.score(X_train,y_train)
print('Train score:', train_score)
# Out:
# Train score: 0.7474726435944634

# %%
# R_2 score after applying Backward Elimination method
score=r2_score(y_test,new_test_pred)
print("r2_score",score)
# Out:
# r2_score 0.7523753802308885

# %%
X_test.shape[1]
# Out:
# 5

# %%
# Calculate R² score
# Number of observations and features
n = len(y_test)
k = X_test.shape[1]

# Calculate Adjusted R²
adjusted_r2 = 1 - (1 - score) * (n - 1) / (n - k - 1)
adjusted_r2
# Out:
# 0.7476497195482719

# %% [markdown]
# # Observation
# Before Backward Elimination(with 8 feature): r_2 score 0.7405079756533047
#
# After applying Backward Elimination(with 5 feature): r2_score 0.7523753802308885

# %%
print("Mean Absolute Error:",metrics.mean_absolute_error(y_test,new_test_pred))
print("Mean Squared  Error:",metrics.mean_squared_error(y_test,new_test_pred))
print("Root Mean squared Error:",np.sqrt(metrics.mean_absolute_error(y_test,new_test_pred)))
# Out:
# Mean Absolute Error: 4385.458853141386
# Mean Squared  Error: 41657844.63326063
# Root Mean squared Error: 66.2227970803211

# %%
new_df=pd.DataFrame({'Actual':y_test,'predicted':new_test_pred,'diffrence':y_test-new_test_pred})
new_df.head()
# Out:
#       Actual     predicted    diffrence
# 1248    1633   5103.701928 -3470.701928
# 610     8547   9750.166971 -1203.166971
# 393     9290  10832.266910 -1542.266910
# 503    32548  26467.677262  6080.322738
# 198     9644   6990.447691  2653.552309

# %%
# Make predictions on the test set
# just tool y_test_pred = model.predict(X_test)
# coressponding to x[198],  prediction= new_model.predict([[1,18,36,0,0]]
prediction= new_model.predict(X_test[267].reshape(1, -1))
prediction
# Out:
# array([14214.48023309])

# %%
# actual value of y
y_test.iloc[267]
# Out:
# 15019

# %%
 # predicted value of y coressponding to x[267]
new_test_pred[267]
# Out:
# 14214.480233090479

# %%
print('Intercept',new_model.intercept_)
# Out:
# Intercept -10844.937666824379

# %%
print('coefficients',new_model.coef_)
# Out:
# coefficients [    0.           245.3480578    295.70191166   488.39048322
#  23779.94448027]

# %%
X_test[267]
# Out:
# array([ 1, 62, 30,  2,  0])

# %%
# actual value of y corressponding to row value 267 mathematically
# y=m1*x1+m2*x2+m3*x3+m4*x4+m5*x5+b
y[267]= 0*1+  245.348*62+295.701525*30+488.397388* 2+ 23779.85656523*0+(-10844.937666824379)

# %%
y[267]
# Out:
# 14214.478859175619
